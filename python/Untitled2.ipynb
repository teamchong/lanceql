# %%
import metal0.lanceql.display
import polars as pl

df = pl.DataFrame({
  'id': range(10),
  'url': ['https://picsum.photos/200/300'] * 10,
  'name': [f'Image {i}' for i in range(10)]
})
df
# Out:
# shape: (10, 3)
# ┌─────┬───────────────────────────────┬─────────┐
# │ id  ┆ url                           ┆ name    │
# │ --- ┆ ---                           ┆ ---     │
# │ i64 ┆ str                           ┆ str     │
# ╞═════╪═══════════════════════════════╪═════════╡
# │ 0   ┆ https://picsum.photos/200/300 ┆ Image 0 │
# │ 1   ┆ https://picsum.photos/200/300 ┆ Image 1 │
# │ 2   ┆ https://picsum.photos/200/300 ┆ Image 2 │
# │ 3   ┆ https://picsum.photos/200/300 ┆ Image 3 │
# │ 4   ┆ https://picsum.photos/200/300 ┆ Image 4 │
# │ 5   ┆ https://picsum.photos/200/300 ┆ Image 5 │
# │ 6   ┆ https://picsum.photos/200/300 ┆ Image 6 │
# │ 7   ┆ https://picsum.photos/200/300 ┆ Image 7 │
# │ 8   ┆ https://picsum.photos/200/300 ┆ Image 8 │
# │ 9   ┆ https://picsum.photos/200/300 ┆ Image 9 │
# └─────┴───────────────────────────────┴─────────┘
