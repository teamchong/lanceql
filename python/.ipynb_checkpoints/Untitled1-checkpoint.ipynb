# %%
 # Import polars FIRST before any path manipulation
  import polars as pl

  # Then load display
  import importlib.util
  spec = importlib.util.spec_from_file_location(
      "lanceql_display",
      "/Users/steven_chong/Downloads/repos/lanceql/python/metal0/lanceql/display.py"
  )
  display = importlib.util.module_from_spec(spec)
  spec.loader.exec_module(display)

  # Test
  df = pl.DataFrame({'id': range(1000), 'name': [f'Item {i}' for i in range(1000)]})
  df
# Out:
#   Cell In[1], line 2
#     import polars as pl
#     ^
# IndentationError: unexpected indent
